# %%
low = 137683
hig = 596253

count_valid = 0
for pw in range(low, hig + 1):
    is_valid = True
    has_double = False
    prev_c = -1

    for c in map(int, str(pw)):
        if c < prev_c: 
            is_valid = False
            
        if c == prev_c:
            has_double = True
                
        prev_c = c
        
    if not has_double: 
        is_valid = False
        
    if is_valid:
        count_valid += 1
        # print(pw)
        
print(f'Answer 1: {count_valid}')
# Out:
# Answer 1: 1864

# %%
count_valid = 0
for pw in range(low, hig + 1):
    is_valid = True
    prev_c = -1
    found_doubles = []
    double_count = 0

    for c in map(int, str(pw)):
        if c < prev_c: 
            is_valid = False
        
        if c == prev_c:
            double_count += 1
            if double_count == 1:
                found_doubles.append(c)
            elif double_count > 1 and c in found_doubles:
                found_doubles.remove(c)
        else:
            double_count = 0
                
        prev_c = c
        
    if len(found_doubles) == 0: 
        is_valid = False
        
    if is_valid:
        count_valid += 1
        print(pw)
        
print(f'Answer 2: {count_valid}')
# Out:
# 137788
# 137789
# 137799
# 137889
# 137899
# 138899
# 144455
# 144466
# 144477
# 144488
# 144499
# 144555
# 144556
# 144557
# 144558
# 144559
# 144566
# 144567
# 144568
# 144569
# 144577
# 144578
# 144579
# 144588
# 144589
# 144599
# 144666
# 144667
# 144668
# 144669
# 144677
# 144678
# 144679
# 144688
# 144689
# 144699
# 144777
# 144778
# 144779
# 144788
# 144789
# 144799
# 144888
# 144889
# 144899
# 144999
# 145566
# 145567
# 145568
# 145569
# 145577
# 145578
# 145579
# 145588
# 145589
# 145599
# 145667
# 145668
# 145669
# 145677
# 145688
# 145699
# 145778
# 145779
# 145788
# 145799
# 145889
# 145899
# 146677
# 146678
# 146679
# 146688
# 146689
# 146699
# 146778
# 146779
# 146788
# 146799
# 146889
# 146899
# 147788
# 147789
# 147799
# 147889
# 147899
# 148899
# 155566
# 155577
# 155588
# 155599
# 155666
# 155667
# 155668
# 155669
# 155677
# 155678
# 155679
# 155688
# 155689
# 155699
# 155777
# 155778
# 155779
# 155788
# 155789
# 155799
# 155888
# 155889
# 155899
# 155999
# 156677
# ...
